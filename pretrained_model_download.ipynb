# %%
from huggingface_hub import snapshot_download

# 1. Motion → Text (short caption)
snapshot_download(
    repo_id="wbz0505/m2t-ft-from-GSPretrained-base",
    local_dir="./m2t-ft-from-GSPretrained-base",
    resume_download=True
)

# 2. Motion → Detailed Text (fine-grained caption)
snapshot_download(
    repo_id="wbz0505/m2dt-ft-from-GSPretrained-base",
    local_dir="./m2dt-ft-from-GSPretrained-base",
    resume_download=True
)

# 3. Granularity-Synergy Pretrained Model (supports ALL tasks)
snapshot_download(
    repo_id="wbz0505/GSPretrained-base",
    local_dir="./GSPretrained_base",
    resume_download=True
)

print("All models downloaded successfully!")
# Out:
# /home/nmt/miniconda3/envs/mg-motionllm/lib/python3.9/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/893M [00:00<?, ?B/s]
# optimizer.pt:   0%|          | 0.00/1.79G [00:00<?, ?B/s]
# All models downloaded successfully!
